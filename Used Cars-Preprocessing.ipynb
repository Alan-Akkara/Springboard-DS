# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

# %%
cars_data = pd.read_csv("cars_data_cleaned.csv")

# %%
cars_data.head()
# Out:
#   manufacturer   mileage   transmission drivetrain fuel_type   mpg  \
# 0        Acura   92945.0      automatic        FWD  gasoline  38.5
# 1        Acura   47645.0  automatic cvt        FWD    hybrid  38.5
# 2        Acura   53422.0  automatic cvt        FWD    hybrid  38.5
# 3        Acura  117598.0  automatic cvt        FWD    hybrid  38.5
# 4        Acura  114865.0  automatic cvt        FWD    hybrid  38.5
#
#   exterior_color interior_color  accidents_or_damage  one_owner  \
# 0          black          other                  0.0        0.0
# 1           gray          ebony                  1.0        1.0
# 2          other          ebony                  0.0        1.0
# 3          other          other                  0.0        1.0
# 4          other          ebony                  1.0        0.0
#
#    personal_use_only seller_name  seller_rating  driver_rating  \
# 0                0.0      Others            4.0            4.0
# 1                1.0      Others            4.0            4.0
# 2                1.0      Others            4.0            4.0
# 3                1.0      Others            4.0            4.0
# 4                1.0      Others            3.0            4.0
#
#    driver_reviews_num    price  car_age
# 0                12.0  13988.0       11
# 1                12.0  17995.0       11
# 2                12.0  17000.0       11
# 3                12.0  14958.0       11
# 4                12.0  14498.0       11

# %%
cars_data = pd.get_dummies(cars_data, drop_first=True)

# %%
cars_data.shape
# Out:
# (690370, 80)

# %%
cars_data.head()
# Out:
#     mileage   mpg  accidents_or_damage  one_owner  personal_use_only  \
# 0   92945.0  38.5                  0.0        0.0                0.0
# 1   47645.0  38.5                  1.0        1.0                1.0
# 2   53422.0  38.5                  0.0        1.0                1.0
# 3  117598.0  38.5                  0.0        1.0                1.0
# 4  114865.0  38.5                  1.0        0.0                1.0
#
#    seller_rating  driver_rating  driver_reviews_num    price  car_age  ...  \
# 0            4.0            4.0                12.0  13988.0       11  ...
# 1            4.0            4.0                12.0  17995.0       11  ...
# 2            4.0            4.0                12.0  17000.0       11  ...
# 3            4.0            4.0                12.0  14958.0       11  ...
# 4            3.0            4.0                12.0  14498.0       11  ...
#
#    interior_color_gray  interior_color_jet black  interior_color_other  \
# 0                False                     False                  True
# 1                False                     False                 False
# 2                False                     False                 False
# 3                False                     False                  True
# 4                False                     False                 False
#
#    seller_name_Adams North Charlotte  seller_name_Auto Boutique  \
# 0                              False                      False
# 1                              False                      False
# 2                              False                      False
# 3                              False                      False
# 4                              False                      False
#
#    seller_name_Automotive Avenues  seller_name_East Coast Auto Source  \
# 0                           False                               False
# 1                           False                               False
# 2                           False                               False
# 3                           False                               False
# 4                           False                               False
#
#    seller_name_Gateway Classic Cars  seller_name_Others  \
# 0                             False                True
# 1                             False                True
# 2                             False                True
# 3                             False                True
# 4                             False                True
#
#    seller_name_Pacific Auto Center - Fontana
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
# [5 rows x 80 columns]

# %%
X = cars_data.drop("price", axis=1)
y = cars_data["price"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
pca = PCA(n_components=0.95, random_state=42)
X_pca = pca.fit_transform(X_scaled)

# %%
print("Original shape:", X.shape)
print("Transformed shape:", X_pca.shape)
print("Number of components selected:", pca.n_components_)
print("Total variance explained:", sum(pca.explained_variance_ratio_))
# Out:
# Original shape: (690370, 79)
# Transformed shape: (690370, 63)
# Number of components selected: 63
# Total variance explained: 0.9514796378370519

# %%
pd.DataFrame(X_pca).to_csv("preprocessed_cars.csv", index=False)
y.to_csv("target_price.csv", index=False)
